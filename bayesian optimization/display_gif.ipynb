# %%
from IPython.display import Image

# %%
Image(filename="./pngs/test/bo.gif")

# %%
Image(filename="./test.gif")

# %%
Image(filename="./pngs/gps/movie.gif")

# %%
for i in np.random.uniform(0, 10, size=(10, 1)):
    print(i)
# Out:
# [1.91438052]
# [4.34892506]
# [3.98860671]
# [5.08694201]
# [5.98327632]
# [4.74571645]
# [2.89416168]
# [5.34655714]
# [8.68937137]
# [0.13549394]

# %%
greater_is_better = False
(-1) ** (not greater_is_better)
# Out:
# -1
